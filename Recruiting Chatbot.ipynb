# %%
print('Hello and welcome to Awesome Jobs.')
print('We will together find a better job for you.')

ui_name   = input('Tell me, what is your full name? ')
ui_city   = input('Which city are you from? ')
ui_gender = input("Great. What's your gender?\nMale \nFemale \nOthers\n")
ui_age    = input('How old are you? ')

print('------------------------')
print('------YOUR DETAILS------')
print('Name   :', ui_name)
print('City   :', ui_city)
print('Gender :', ui_gender)
print('Age    :', ui_age)
print('------------------------')

print('This is exciting.')
print('I already have found more than 300 jobs that you might like.')
print('What kind of jobs do you like?')

category = {1:{'name': 'Teaching',         'avg_sal':35000},
            2:{'name': 'Software Engineer','avg_sal':55000},
            3:{'name': 'Head Chef',        'avg_sal':45000},
            4:{'name': 'Advocate',         'avg_sal':45000},
            5:{'name': 'Technician',       'avg_sal':35000}
           }
print(category)

ui_catip1, ui_catip2, ui_catip3 = map(int,input('Select your 3 categories\n').split())


sal_opt = {1:'15000-20000',2:'20000 - 25000',3:'25000 - 30000',4:'30000 - 35000'}
print('How much monthly salary do you expect?\n')
ui_sal = int(input(sal_opt))


print('Great. Here’s a list of great jobs you might like.')

print('----------------------------')
print('-------JOBS--FOR--YOU-------')
if(ui_catip1 == 1 or ui_catip2 == 1 or ui_catip3 == 1):
    print('Arihant Coachings\n Rs 17000/month')
    print('Aakash Institute\n Rs 20000/month ')
    print('Unacademy\n Rs 35000/month')
if(ui_catip1 == 2 or ui_catip2 == 2 or ui_catip3 == 2):
    print('Avent\n Rs 47000/month')
    print('Cognizant Institute\n Rs 55000/month ')
    print('Unthinkable Solutions\n Rs 45000/month')
if(ui_catip1 == 3 or ui_catip2 == 3 or ui_catip3 == 3):
    print('Chinese Special\n Rs 17000/month')
    print('Spiced Chille\n Rs 20000/month ')
    print('Wow Momos\n Rs 35000/month')
if(ui_catip1 == 4 or ui_catip2 == 4 or ui_catip3 == 4):
    print('Professional Utilities \n Rs 27000/month')
    print('Allied Legal\n Rs 32000/month ')
    print('TalentPad\n Rs 35000/month')
if(ui_catip1 == 5 or ui_catip2 == 5 or ui_catip3 == 5):
    print('ITI Technician \n Rs 27000/month')
    print('Bagson Collaboration\n Rs 22000/month ')
    print('Astreya\n Rs 15000/month')

print('-----If you like them, select one to apply for it.-----')
ui_job = input('Enter the company name where you want to apply: ')

record = ui_name +","+ ui_city +","+ ui_gender +","+ ui_age +","+ ui_job +'\n'
# Out:
# Hello and welcome to Awesome Jobs.
# We will together find a better job for you.
# Tell me, what is your full name? Anuradha Kumari
# Which city are you from? New Delhi
# Great. What's your gender?
# Male
# Female
# Others
# Female
# How old are you? 21
# ------------------------
# ------YOUR DETAILS------
# Name   : Anuradha Kumari
# City   : New Delhi
# Gender : Female
# Age    : 21
# ------------------------
# This is exciting.
# I already have found more than 300 jobs that you might like.
# What kind of jobs do you like?
# {1: {'name': 'Teaching', 'avg_sal': 35000}, 2: {'name': 'Software Engineer', 'avg_sal': 55000}, 3: {'name': 'Head Chef', 'avg_sal': 45000}, 4: {'name': 'Advocate', 'avg_sal': 45000}, 5: {'name': 'Technician', 'avg_sal': 35000}}
# Select your 3 categories
# 1 2 4
# How much monthly salary do you expect?
#
# {1: '15000-20000', 2: '20000 - 25000', 3: '25000 - 30000', 4: '30000 - 35000'}2
# Great. Here’s a list of great jobs you might like.
# ...

# %%
fd = open('recruit.txt', 'w')

fd.write(record)

fd.close()
